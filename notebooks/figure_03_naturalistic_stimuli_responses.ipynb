# %% [markdown]
# # Figure 3

# %%
# %load_ext autoreload
# %autoreload 2

from flyvision import EnsembleView

# %%
ensemble = EnsembleView("flow/0000")
# Out:
# Loading ensemble:   0%|          | 0/50 [00:00<?, ?it/s]
# [2024-09-09 22:25:46] Loaded 50 networks.

# %% [markdown]
# ## a

# %%
task_error = ensemble.task_error()

# %%
embedding_and_clustering = ensemble.clustering("T4c")
# Out:
# [2024-09-09 22:25:48] Loaded T4c embedding and clustering from /groups/turaga/home/lappalainenj/FlyVis/private/flyvision/data/results/flow/0000/umap_and_clustering.

# %%
embeddingplot = embedding_and_clustering.plot(task_error=task_error.values, colors=task_error.colors)

# %% [markdown]
# ## b

# %%
import numpy as np
import matplotlib.pyplot as plt

from flyvision.analysis.clustering import check_markers
from flyvision.utils.activity_utils import CellTypeArray
from flyvision.plots import plt_utils 
from flyvision.plots import plots
from flyvision.datasets import MovingEdge
from flyvision.analysis.moving_bar_responses import MovingEdgeResponseView
from flyvision.utils.groundtruth_utils import tuning_curves

# %%
cluster_indices = ensemble.cluster_indices("T4c")
# Out:
# [2024-09-09 22:25:49] Loaded T4c embedding and clustering from /groups/turaga/home/lappalainenj/FlyVis/private/flyvision/data/results/flow/0000/umap_and_clustering.

# %%
dataset = MovingEdge(
                offsets=[-10, 11],
                intensities=[0, 1],
                # this is the full sets of speeds used originally: [2.4, 4.8, 9.7, 13, 19, 25]
                speeds=[19],
                height=80,
                post_pad_mode="continue",
                t_pre=1.0,
                t_post=1.0,
                dt=1 / 200,
                angles=list(np.arange(0, 360, 30)),
            )
responses = np.stack(
    list(
        ensemble.simulate_from_dataset(
            dataset,
            dt=dataset.dt,
            batch_size=4,
            central_cell_only=True,
        )
    )
)
# Out:
# Simulating network:   0%|          | 0/50 [00:00<?, ?it/s]
# [2024-09-09 22:25:59] Initialized network with NumberOfParams(free=734, fixed=2959) parameters.
# [2024-09-09 22:25:59] Recovered network state.
# [2024-09-09 22:25:59] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:26:04] Recovered network state.
# [2024-09-09 22:26:04] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:26:08] Recovered network state.
# [2024-09-09 22:26:08] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:26:13] Recovered network state.
# [2024-09-09 22:26:13] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:26:18] Recovered network state.
# [2024-09-09 22:26:18] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:26:22] Recovered network state.
# [2024-09-09 22:26:22] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:26:27] Recovered network state.
# [2024-09-09 22:26:27] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:26:31] Recovered network state.
# [2024-09-09 22:26:31] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:26:36] Recovered network state.
# [2024-09-09 22:26:36] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:26:40] Recovered network state.
# [2024-09-09 22:26:41] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:26:45] Recovered network state.
# [2024-09-09 22:26:45] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:26:50] Recovered network state.
# [2024-09-09 22:26:50] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:26:54] Recovered network state.
# [2024-09-09 22:26:54] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:26:59] Recovered network state.
# [2024-09-09 22:26:59] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:27:04] Recovered network state.
# [2024-09-09 22:27:04] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:27:08] Recovered network state.
# [2024-09-09 22:27:08] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:27:13] Recovered network state.
# [2024-09-09 22:27:13] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:27:17] Recovered network state.
# [2024-09-09 22:27:18] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:27:22] Recovered network state.
# [2024-09-09 22:27:22] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:27:27] Recovered network state.
# [2024-09-09 22:27:27] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:27:31] Recovered network state.
# [2024-09-09 22:27:31] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:27:36] Recovered network state.
# [2024-09-09 22:27:36] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:27:41] Recovered network state.
# [2024-09-09 22:27:41] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:27:45] Recovered network state.
# [2024-09-09 22:27:45] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:27:50] Recovered network state.
# [2024-09-09 22:27:50] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:27:55] Recovered network state.
# [2024-09-09 22:27:55] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:27:59] Recovered network state.
# [2024-09-09 22:27:59] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:28:04] Recovered network state.
# [2024-09-09 22:28:04] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:28:09] Recovered network state.
# [2024-09-09 22:28:09] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:28:13] Recovered network state.
# [2024-09-09 22:28:13] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:28:18] Recovered network state.
# [2024-09-09 22:28:18] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:28:22] Recovered network state.
# [2024-09-09 22:28:23] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:28:27] Recovered network state.
# [2024-09-09 22:28:27] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:28:32] Recovered network state.
# [2024-09-09 22:28:32] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:28:36] Recovered network state.
# [2024-09-09 22:28:37] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:28:41] Recovered network state.
# [2024-09-09 22:28:41] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:28:46] Recovered network state.
# [2024-09-09 22:28:46] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:28:51] Recovered network state.
# [2024-09-09 22:28:51] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:28:55] Recovered network state.
# [2024-09-09 22:28:55] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:29:00] Recovered network state.
# [2024-09-09 22:29:00] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:29:05] Recovered network state.
# [2024-09-09 22:29:05] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:29:09] Recovered network state.
# [2024-09-09 22:29:09] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:29:14] Recovered network state.
# [2024-09-09 22:29:14] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:29:19] Recovered network state.
# [2024-09-09 22:29:19] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:29:23] Recovered network state.
# [2024-09-09 22:29:24] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:29:28] Recovered network state.
# [2024-09-09 22:29:28] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:29:33] Recovered network state.
# [2024-09-09 22:29:33] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:29:37] Recovered network state.
# [2024-09-09 22:29:38] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:29:42] Recovered network state.
# [2024-09-09 22:29:42] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]
# [2024-09-09 22:29:47] Recovered network state.
# [2024-09-09 22:29:47] Computing 24 stimulus responses.
# Batch:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
responses_cta = CellTypeArray(
    responses,
    connectome=ensemble[0].connectome,
)

# %%
response_view = MovingEdgeResponseView(
    arg_df=dataset.arg_df,
    responses=responses_cta,
    config=dataset.config,
    stim_sample_dim=1,
    temporal_dim=2,
)

# %%
cluster_colors = {}
CMAPS = ["Greens_r", "Reds_r", "Reds_r"]

for cluster_id in cluster_indices:
    cluster_colors[cluster_id] = ensemble.task_error(cmap=CMAPS[cluster_id]).colors

# %%
task_error_sorting = np.argsort(ensemble.task_error().values)

# %%
measured_tuning = np.array(tuning_curves["T4c"])
theta = np.linspace(0, 360, len(measured_tuning), endpoint=True)

# %%
response_view["T4c"]
# Out:
# MovingEdgeResponseView(    angle  width  intensity    t_stim  speed
# 0       0     80          0  0.428766     19
# 1       0     80          1  0.428766     19
# 2      30     80          0  0.428766     19
# 3      30     80          1  0.428766     19
# 4      60     80          0  0.428766     19
# 5      60     80          1  0.428766     19
# 6      90     80          0  0.428766     19
# 7      90     80          1  0.428766     19
# 8     120     80          0  0.428766     19
# 9     120     80          1  0.428766     19
# 10    150     80          0  0.428766     19
# 11    150     80          1  0.428766     19
# 12    180     80          0  0.428766     19
# 13    180     80          1  0.428766     19
# 14    210     80          0  0.428766     19
# 15    210     80          1  0.428766     19
# 16    240     80          0  0.428766     19
# 17    240     80          1  0.428766     19
# 18    270     80          0  0.428766     19
# 19    270     80          1  0.428766     19
# 20    300     80          0  0.428766     19
# 21    300     80          1  0.428766     19
# 22    330     80          0  0.428766     19
# 23    330     80          1  0.428766     19, {'T4c': 'Array((50, 24, 485))'}, 0.005, 1, 2)

# %%
fig, axes = plt.subplots(1, len(cluster_indices), subplot_kw={'projection': 'polar'},
                         figsize=[2, 1])
for cluster_id, model_ids in cluster_indices.items():
    ax = axes[cluster_id]
    response_view[model_ids, :, :].plot_angular_tuning(
        cell_type="T4c",
        intensity=1,
        colors=task_error.colors[model_ids],
        fig=fig,
        ax=ax,
        zorder=task_error_sorting[model_ids][::-1],
    )


n_clusters = len(cluster_indices)

axes = np.atleast_2d(axes)
MARKERS = check_markers(n_clusters)
for column in range(axes.shape[1]):
    marker = MARKERS[column]
    plt_utils.add_cluster_marker(
        fig, axes[-1, column], marker=marker, color="#4F73AE", marker_size=10,
    )

plots.polar(
    theta,
    measured_tuning / measured_tuning.max(),
    fig=fig,
    ax=axes[0, 0],
    color="k",
    linewidth=1,
    fontsize=5,
    anglepad=-6,
)
# Out:
# (<Figure size 600x300 with 4 Axes>, <PolarAxes: >)

# %% [markdown]
# ## e

# %%
for cluster_id, indices in cluster_indices.items():
    with ensemble.select_items(indices):
        fig, ax = ensemble.flash_response_indices(cell_types=["Mi1", "Tm3", "Mi4", "Mi9", "CT1(M10)"],
                                        figsize=[1, 1])
# Out:
# [2024-09-09 22:29:54] No recordings found in flash_responses/chkpt_best_validation_loss. Run the analysis script for synthetic recordings to precompute them.
# [2024-09-09 22:29:54] Computing responses.
# Simulating network:   0%|          | 0/31 [00:00<?, ?it/s]
# [2024-09-09 22:29:55] Recovered network state.
# [2024-09-09 22:29:56] Recovered network state.
# [2024-09-09 22:29:58] Recovered network state.
# [2024-09-09 22:29:59] Recovered network state.
# [2024-09-09 22:30:00] Recovered network state.
# [2024-09-09 22:30:01] Recovered network state.
# [2024-09-09 22:30:02] Recovered network state.
# [2024-09-09 22:30:03] Recovered network state.
# [2024-09-09 22:30:05] Recovered network state.
# [2024-09-09 22:30:06] Recovered network state.
# [2024-09-09 22:30:07] Recovered network state.
# [2024-09-09 22:30:08] Recovered network state.
# [2024-09-09 22:30:09] Recovered network state.
# [2024-09-09 22:30:10] Recovered network state.
# [2024-09-09 22:30:11] Recovered network state.
# [2024-09-09 22:30:13] Recovered network state.
# [2024-09-09 22:30:14] Recovered network state.
# [2024-09-09 22:30:15] Recovered network state.
# [2024-09-09 22:30:16] Recovered network state.
# [2024-09-09 22:30:17] Recovered network state.
# [2024-09-09 22:30:18] Recovered network state.
# [2024-09-09 22:30:20] Recovered network state.
# [2024-09-09 22:30:21] Recovered network state.
# [2024-09-09 22:30:22] Recovered network state.
# [2024-09-09 22:30:23] Recovered network state.
# [2024-09-09 22:30:24] Recovered network state.
# [2024-09-09 22:30:25] Recovered network state.
# [2024-09-09 22:30:26] Recovered network state.
# [2024-09-09 22:30:28] Recovered network state.
# [2024-09-09 22:30:29] Recovered network state.
# [2024-09-09 22:30:31] No recordings found in flash_responses/chkpt_best_validation_loss. Run the analysis script for synthetic recordings to precompute them.
# [2024-09-09 22:30:31] Computing responses.
# Simulating network:   0%|          | 0/7 [00:00<?, ?it/s]
# [2024-09-09 22:30:33] Recovered network state.
# [2024-09-09 22:30:34] Recovered network state.
# [2024-09-09 22:30:35] Recovered network state.
# [2024-09-09 22:30:36] Recovered network state.
# [2024-09-09 22:30:37] Recovered network state.
# [2024-09-09 22:30:38] Recovered network state.
# [2024-09-09 22:30:40] No recordings found in flash_responses/chkpt_best_validation_loss. Run the analysis script for synthetic recordings to precompute them.
# [2024-09-09 22:30:40] Computing responses.
# Simulating network:   0%|          | 0/12 [00:00<?, ?it/s]
# [2024-09-09 22:30:41] Recovered network state.
# [2024-09-09 22:30:42] Recovered network state.
# [2024-09-09 22:30:43] Recovered network state.
# [2024-09-09 22:30:45] Recovered network state.
# [2024-09-09 22:30:46] Recovered network state.
# [2024-09-09 22:30:47] Recovered network state.
# [2024-09-09 22:30:48] Recovered network state.
# [2024-09-09 22:30:49] Recovered network state.
# [2024-09-09 22:30:50] Recovered network state.
# [2024-09-09 22:30:52] Recovered network state.
# [2024-09-09 22:30:53] Recovered network state.
